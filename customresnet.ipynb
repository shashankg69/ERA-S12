# %%
# !git clone https://github.com/shashankg69/ERA-S12
# %cd ERA-S12/
# !git pull
# !pip install -qr requirements.txt
# Out:
# fatal: destination path 'ERA-S12' already exists and is not an empty directory.
# /kaggle/working/ERA-S12
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 2 (delta 1), reused 2 (delta 1), pack-reused 0
# Unpacking objects: 100% (2/2), 204 bytes | 204.00 KiB/s, done.
# From https://github.com/shashankg69/ERA-S12
#    653e6f0..cc2a5fe  main       -> origin/main
# Updating 653e6f0..cc2a5fe
# Fast-forward
#  .../version_0/checkpoints/epoch=0-step=98.ckpt     | Bin 26337612 -> 0 bytes
#  lightning_logs/version_0/hparams.yaml              |   1 -
#  lightning_logs/version_0/metrics.csv               |   2 -
#  .../version_1/checkpoints/epoch=0-step=98.ckpt     | Bin 26336972 -> 0 bytes
#  lightning_logs/version_1/hparams.yaml              |   1 -
#  lightning_logs/version_1/metrics.csv               |   5 --
#  s12.ipynb                                          |  95 ---------------------
# ...

# %%
from utils import set_seed
set_seed(42)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch_lr_finder/lr_finder.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# ...

# %%
from Dataset import CIFAR10
batch_size = 512
cifar10 = CIFAR10(batch_size)

from models.CustomResNet import CustomResNet
from utils.runner import Runner
model = CustomResNet(cifar10)
exp = Runner(model, precision='16-mixed')
exp.run()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/100 [00:00<?, ?it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 2.48E-04
# Sanity Checking: 0it [00:00, ?it/s]
# Files already downloaded and verified
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs/
# Out:
#       <iframe id="tensorboard-frame-bf14e59a23b291ee" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-bf14e59a23b291ee");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
exp.show_incorrect()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Predicting: 0it [00:00, ?it/s]
# /kaggle/working/ERA-S12/utils/get_device.py:39: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
exp.show_incorrect(cams=True, target_layer=model.network[3])
